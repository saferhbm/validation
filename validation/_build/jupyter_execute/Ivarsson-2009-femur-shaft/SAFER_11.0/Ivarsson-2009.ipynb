# %% [markdown]
# # Ivarsson et al. (2009): Femur shaft Bending and axial compression

# %% [markdown]
# - Performed by: Yash Niranjan Poojary
# - Reviewed by:
# - Last modified : 27nd December 2023
# - SAFER HBM Version: ![Static Badge](https://img.shields.io/badge/SAFER_HBM-11.0-1?style=flat&logoColor=blue&labelColor=whitw&color=blue)
# - LSDYNA version:  `mpp d R12.1.0 `

# %% [markdown]
# ## Experiment by  Ivarsson (2009)
#
# ### Summary:
#
# The simulated outputs are compared to the references from PMHS tests reported by  Ivarsson  <sup>[1]</sup>
# 1. IVARSSON, B. Johan, et al. The tolerance of the femoral shaft in combined axial compression and bending loading. Stapp car crash journal, 2009, 53: 251.
#
# <!-- ![](../_env/setup_ivarsson_femur.PNG)  -->
# ```{figure} ../_env/setup_ivarsson_femur.PNG
# ---
# align: center
# ---
# Setups in testing
# ```

# %% [markdown]
# ## Experiment
# ### Information on the subjects/specimens
# | Test ID | Subject ID | Age (yrs) | Sex |    Loading mode   |
# |:-------:|:----------:|:---------:|:---:|:-----------------:|
# |   1.01  |     373    |     51    |  M  | Combined Loading  |
# |   1.02  |     373    |     51    |  M  | Combined Loading  |
# |   1.03  |     374    |     62    |  M  | Combined Loading  |
# |   1.04  |     374    |     62    |  M  | Combined Loading  |
# |   1.05  |     375    |     62    |  M  | Combined Loading  |
# |   1.06  |     375    |     62    |  M  | Combined Loading  |
# |   1.07  |     376    |     49    |  M  | Combined Loading  |
# |   1.08  |     376    |     49    |  M  | Combined Loading  |
# |   1.09  |     377    |     62    |  M  | Combined Loading  |
# |   1.1   |     378    |     44    |  M  | Combined Loading  |
# |   1.11  |     378    |     44    |  M  | Combined Loading  |
# |   1.12  |     379    |     58    |  M  | Combined Loading  |
# |   1.13  |     379    |     58    |  M  | Combined Loading  |
# |   1.14  |     380    |     65    |  M  | Combined Loading  |
# |   1.15  |     380    |     65    |  M  | Combined Loading  |
# |   1.16  |     381    |     53    |  M  | Combined Loading  |
# |   1.17  |     381    |     53    |  M  | Combined Loading  |
# |   1.30  |     385    |     62    |  M  | Combined Loading  |
# |   1.34  |     390    |     63    |  M  | Bending           |
# |   1.37  |     392    |     45    |  M  | Bending           |
# |   1.38  |     392    |     45    |  M  | Bending           |
# |   2.06  |     327    |     39    |  M  | Bending           |
# |  2.07b  |     362    |     51    |  M  | Bending           |
# |  2.03b  |     203    |     67    |  M  | Axial compression |
# |   2.05  |     327    |     39    |  M  | Axial compression |
# |  2.07a  |     362    |     51    |  M  | Axial compression |
# |   2.08  |     362    |     51    |  M  | Axial compression |
#
#
#
# ### Loading and Boundary Conditions
# - 23 male specimens tested for axial compression, bending and combined loading.
# - The potting cups are made of PMMA were defined with youngs modulus 3.1 GPa, poissons ratio 0.3 and density $1180 kg/m^3$
# - The linear bearings were defined as rigid parts youngs modulus 70 GPa, poissons ratio 0.34 and density $2700 kg/m^3$
# - A foam material for bending and combined load cases was defined using MAT57 (`*MAT_LOW_DENSITY_FOAM`) material with a nominal stress versus strain curve extracted from the litrture and density 15.6 $kg/m^3$. Two layers of 1 mm belytschko-tsay shell elements were generated as `MAT_NULL_SHELLS` to prevent penetrations.
# - The ends of the femur shaft was aligned with the line connecting the centre of rotation of the potting cups.
# - Each potting cup-holder, with linear bearings, were modelled as a revolute joint.
# - The right cup, cup-holder and linear bearing was allowed to translate in X-direction, other degrees of freedom were
# - restricted. Each of the 23 tests were modelled with associated prescribed displacement from the litrature
# ### Responses recorded
# - force-time  measured at the contact.
# - displacement time of the impactor.
#
# The reference values from the paper were digitalised and are incuded in the notebook
#
# ### Other references
# 2.	Drevon D, Fursa SR, Malcolm AL. Intercoder reliability and validity of WebPlotDigitizer in extracting graphed data. Behavior modification. 2017;41(2):323-39.
# 3.	Svensson, Gustav. ["Finite Element Modelling of Knee Joint and Femur for Future Injury Assessment"](https://odr.chalmers.se/handle/20.500.12380/305815) (2022).

# %%
import os
import glob
# for data analysis
import pandas as pd
import numpy as np

# %%
 # Libraries for plotting
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
sns.set_style("whitegrid")
sns.set_context("paper", font_scale=1)
experiment = {"linestyle" :'--', "color" : 'k',"alpha" : 0.7}
simulation = {"linestyle" :'-', "color" : 'b',"alpha" : 0.7,"linewidth":2}
# Dataframe formats
def select_col(x):
    mask = x['Overall Score'] <0.5
    df1 =  pd.DataFrame('', index=x.index, columns=x.columns)
    df1.loc[mask,'Overall Score'] = 'color:crimson;font-weight:bold;'
    return df1
heading = [dict(selector="caption",
            props=[("text-align", "center"),
                   ("font-size", "150%"),
                   ("font-weight", "bold")])]
content={'text-align': 'center'}

# %%
Tests=['1_01' , '1_02', '1_03', '1_04', '1_05',
       '1_06', '1_07', '1_08' , '1_09', '1_10',
       '1_11', '1_12', '1_13', '1_14', '1_15',
       '1_16', '1_17' , '1_30', '1_34', '1_37',
       '1_38', '2_06', '2_07b']


figures_dir = "../data/processed/SAFER_11.0/figures/"
processed_data_dir = f"../data/processed/SAFER_11.0"
experiment_dir= "../data/experiment_data/"
binout_path_sim={}
result_output_dir={}

if not os.path.exists(processed_data_dir): 
    os.makedirs(processed_data_dir)
if not os.path.exists(figures_dir): 
    os.makedirs(figures_dir)

for test in Tests:
    binout_path_sim[test] = test
    result_output_dir[test] = os.path.join(processed_data_dir, binout_path_sim[test])
    if not os.path.exists(result_output_dir[test]): 
        os.makedirs(result_output_dir[test])

# %% [markdown]
# ## Postprocessing with dynasaur

# %%
# Import the dynasaur library
from dynasaur.plugins.data_visualization_controller import DataVisualizationController

# %%
# Path to Dynasaur definition files

# Dynasaur object definitions
dynasaur_ids = ["../_env/id-V11.def"]

# Dynasaur calculation definitions
dynasaur_calculation_defs = [ "../_env/post.def", "../_env/strain_calc.def","../../model/SAFER_11.0/postprocessing/01_energy_calculation.def"]
# dynasaur_calculation_defs = [ "../_env/post.def", "../_env/strain_calc.def", "../_env/stress_calc.def"]

# %%
sim_output={}
exp={}
for test in Tests:
    sim_M = DataVisualizationController(calculation_procedure_def_file=dynasaur_calculation_defs,
                                                  object_def_file=dynasaur_ids,
                                                  data_source= binout_path_sim[test] +'/binout*')
    commands = sim_M.get_defined_calculation_procedures()
    print(commands)
    for command in sim_M.get_defined_calculation_procedures():
        sim_M.calculate(command)
    # export post-processed data
    sim_M.write_CSV(result_output_dir[test], filename="Dynasaur_output.csv")
    # Import processed data
    sim_output[test]=pd.read_csv(os.path.join(result_output_dir[test],"Dynasaur_output.csv"), delimiter=';', na_values='-', header = [0,1,2,3])
# Out:
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 4.588295936584473
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.5620043277740479
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 3.9502317905426025
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.443042278289795
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_01
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_01\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 4.23107385635376
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.4350407123565674
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 3.993144989013672
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.4760055541992188
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_02
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_02\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 4.218931674957275
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.4670178890228271
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 4.00129508972168
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.4630072116851807
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_03
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_03\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 4.187924146652222
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.4510390758514404
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 4.0024614334106445
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.4080054759979248
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_04
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_04\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 4.194340467453003
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.4560811519622803
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 3.869112730026245
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.5139942169189453
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_05
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_05\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 4.400361061096191
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.4840056896209717
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 4.016561269760132
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.4570426940917969
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_06
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_06\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 4.273554086685181
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.4620001316070557
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 3.905857801437378
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.458005428314209
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_07
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_07\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 3.93698787689209
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.4120376110076904
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 3.6912448406219482
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.3350050449371338
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_08
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_08\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 4.38525652885437
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.5030124187469482
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 3.7436795234680176
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.4630417823791504
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_09
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_09\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 4.168761968612671
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.4880504608154297
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 3.9310109615325928
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.4389567375183105
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_10
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_10\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 4.16684365272522
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.4810402393341064
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 4.0078184604644775
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.461008071899414
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_11
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_11\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 4.048484802246094
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.5239996910095215
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 3.808272123336792
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.444037675857544
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_12
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_12\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 4.033090829849243
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.4409990310668945
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 3.884958505630493
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.447035789489746
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_13
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_13\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 4.154225826263428
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.4490301609039307
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 3.935041666030884
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.5190010070800781
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_14
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_14\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 4.236559867858887
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.4970366954803467
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 3.7950010299682617
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.4429714679718018
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_15
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_15\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 4.0706236362457275
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.4330024719238281
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 3.9386329650878906
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.428035020828247
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_16
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_16\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 4.079035043716431
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.4899954795837402
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 3.866941452026367
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.5069737434387207
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_17
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_17\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 4.137786865234375
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.446998119354248
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 3.9466774463653564
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.4750292301177979
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_30
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_30\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 4.173884391784668
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.2659931182861328
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 3.875227451324463
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.242025375366211
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_34
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_34\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 4.218244552612305
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.2900340557098389
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 3.8158724308013916
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.2599983215332031
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_37
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_37\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 4.102820873260498
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.1599979400634766
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 3.8058276176452637
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.1600008010864258
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_38
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_38\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 4.026817798614502
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.2600362300872803
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 3.9430058002471924
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.3090391159057617
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\2_06
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\2_06\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 4.23828387260437
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.2359955310821533
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 3.911540985107422
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 1.2570343017578125
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\2_07b
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\2_07b\Dynasaur_output.csv

# %%
# Import experimental data
exp=pd.read_csv(os.path.join(experiment_dir,'Ivarsson_et_al_2009_impactor_force.csv'.format(test)),delimiter=';',header=[0])
exp_axl=pd.read_csv(os.path.join(experiment_dir,'Ivarsson_et_al_2009_axial_force.csv'.format(test)),delimiter=';',header=[0])

# %% [markdown]
# ### Combined loading

# %%
fig_ft, axs = plt.subplots(nrows=9, ncols=2,figsize=(7, 20))
Age=['51' , '51', '62', '62', '62','62', '49', '49', '62', '44','44', '58' , '58', '65', '65','53', '53', '62', '63', '45','45', '39', '51']
sp_pos=['PA' , 'PA', 'PA', 'PA', 'AP','PA', 'PA', 'AP', 'AP', 'PA','PA', 'AP' , 'AP', 'AP', 'PA','AP', 'AP', 'PA', 'AP', 'AP','PA', 'AP', 'PA']
start_time=[26,28,27,28,18,24,25,17,15,26,25,16,17,17,30,20,16,34,17,17,24,17,22]
i=0
for ax in axs.flat:
    ax.set_ylabel('Force[kN]')
    ax.set_xlabel('Time [ms]');
    if i > 17:
        break;
    ax.set_title('{} | AF= {:.1f}kN | M-{} year | {}'.format(Tests[i],max((exp_axl[Tests[i]])),Age[i],sp_pos[i]),fontsize=13)
    fail_2p=sim_output[Tests[i]].BONES.strain.time.iloc[sim_output[Tests[i]].BONES.strain.strain[sim_output[Tests[i]].BONES.strain.strain<0.0275].last_valid_index()][0]
    t=exp.Time[exp[Tests[i]]==max(exp[Tests[i]])].item()
    ax.set_xlim([0,50])
    ax.set_ylim([0,10])
    ax.plot(sim_output[Tests[i]].impactor.Force.time.iloc[:round(t*10)+1],sim_output[Tests[i]].impactor.Force.force.iloc[:round(t*10)+1],**simulation)
    ax.plot(exp.Time,exp[Tests[i]],label='Test',**experiment)
    ax.axvline (x=t,linestyle='--',color='r')
    ax.axvline (x=fail_2p,linestyle='--',color='y')
    i=i+1
# fig_ft.delaxes(axs[4,2])
# fig_ft.delaxes(axs[4,3])
fig_ft.legend(["SAFER11.0","Test","Test stopped","Model plastic-strain >2%"], bbox_to_anchor=(0.85,0),ncols=4);
fig_ft.tight_layout()

# %% [markdown]
# #### ISO18571 objective rating for force-time histories

# %%
# Import objective rating metric library
from objective_rating_metrics.rating import ISO18571

# %%
## Resample data
def resam(xdata,ydata,sT,endtime):
    x = xdata
    y = ydata
    # Interpolate the data to the desired length
    newx = np.arange(sT,endtime,0.1)#10kHz resolution
    newy = np.interp(newx, x, y)
    return np.array(newx).flatten(),np.array(newy).flatten()    
df_res = pd.DataFrame(columns=['Test','Corridor Score', 'Phase Score', 'Magnitude Score', 'Slope Score', 'Overall Score'])
i=0
for test in Tests:
    endT=0
    if test=='1_34':
        break;
    endT=sim_output[test].BONES.strain.time.iloc[sim_output[test].BONES.strain.strain[sim_output[test].BONES.strain.strain<0.0275].last_valid_index()][0]
    if endT>exp.Time[exp[Tests[i]]==max(exp[Tests[i]])].item():
        endT=exp.Time[exp[Tests[i]]==max(exp[Tests[i]])].item()
    df_rate = pd.DataFrame(columns=['Test','Corridor Score', 'Phase Score', 'Magnitude Score', 'Slope Score', 'Overall Score'])
    if endT>start_time[i]:
        exp_v=exp[test].dropna()
        exp_t=exp.Time[:len(exp_v)].dropna()
        sim_t=np.array(sim_output[test].impactor.Force.time).flatten()
        sim_v=np.array(sim_output[test].impactor.Force.force).flatten()
        r_t,r_v=resam(exp_t,exp_v,start_time[i],endT)
        ref = np.vstack((r_t, r_v)).T
        s_t,s_v=resam(sim_t,sim_v,start_time[i],endT)
        sim = np.vstack((s_t, s_v)).T
        iso_rating = ISO18571(reference_curve=ref, comparison_curve=sim)
        df_rate['Test']=[test]
        df_rate['Corridor Score']=[iso_rating.corridor_rating()]
        df_rate['Phase Score']=[iso_rating.phase_rating()]
        df_rate['Magnitude Score']=[iso_rating.magnitude_rating()]
        df_rate['Slope Score']=[iso_rating.slope_rating()]
        df_rate['Overall Score']=[iso_rating.overall_rating()]
    df_res=pd.concat([df_res,df_rate], ignore_index=True)
    i=i+1

# %%
B1={'width' : 0.5 , 'color':'b','alpha':1, 'edgecolor':'k'}

fig, ax = plt.subplots(figsize=(6, 4))
br1 = np.arange(len(df_res))
ax.bar(br1,df_res['Overall Score'].values,**B1)

plt.xticks(range(len(df_res)), df_res['Test'], rotation=90)
ax.set_ylim([0,1])
ax.set_yticks([0.5,0.58,0.80,0.94,1])
ax.grid(axis='x')
ax.set_title('ISO18571',fontsize=20,fontweight='bold')
fig.tight_layout()
print('Average: {} \nRange: {}-{}'.format(df_res['Overall Score'].mean().round(2),
                                           min(df_res['Overall Score'].round(2)),
                                           max(df_res['Overall Score'].round(2))))

df_res.style.apply(select_col, axis=None).format(precision=2).set_caption("ISO 18571 results").set_table_styles(heading).set_properties(**content)
# Out:
# Average: 0.77
# Range: 0.48-0.95
# <style type="text/css">
# #T_c028f caption {
#   text-align: center;
#   font-size: 150%;
#   font-weight: bold;
# }
# #T_c028f_row0_col0, #T_c028f_row0_col1, #T_c028f_row0_col2, #T_c028f_row0_col3, #T_c028f_row0_col4, #T_c028f_row0_col5, #T_c028f_row1_col0, #T_c028f_row1_col1, #T_c028f_row1_col2, #T_c028f_row1_col3, #T_c028f_row1_col4, #T_c028f_row1_col5, #T_c028f_row2_col0, #T_c028f_row2_col1, #T_c028f_row2_col2, #T_c028f_row2_col3, #T_c028f_row2_col4, #T_c028f_row2_col5, #T_c028f_row3_col0, #T_c028f_row3_col1, #T_c028f_row3_col2, #T_c028f_row3_col3, #T_c028f_row3_col4, #T_c028f_row3_col5, #T_c028f_row4_col0, #T_c028f_row4_col1, #T_c028f_row4_col2, #T_c028f_row4_col3, #T_c028f_row4_col4, #T_c028f_row4_col5, #T_c028f_row5_col0, #T_c028f_row5_col1, #T_c028f_row5_col2, #T_c028f_row5_col3, #T_c028f_row5_col4, #T_c028f_row5_col5, #T_c028f_row6_col0, #T_c028f_row6_col1, #T_c028f_row6_col2, #T_c028f_row6_col3, #T_c028f_row6_col4, #T_c028f_row6_col5, #T_c028f_row7_col0, #T_c028f_row7_col1, #T_c028f_row7_col2, #T_c028f_row7_col3, #T_c028f_row7_col4, #T_c028f_row7_col5, #T_c028f_row8_col0, #T_c028f_row8_col1, #T_c028f_row8_col2, #T_c028f_row8_col3, #T_c028f_row8_col4, #T_c028f_row8_col5, #T_c028f_row9_col0, #T_c028f_row9_col1, #T_c028f_row9_col2, #T_c028f_row9_col3, #T_c028f_row9_col4, #T_c028f_row9_col5, #T_c028f_row10_col0, #T_c028f_row10_col1, #T_c028f_row10_col2, #T_c028f_row10_col3, #T_c028f_row10_col4, #T_c028f_row10_col5, #T_c028f_row11_col0, #T_c028f_row11_col1, #T_c028f_row11_col2, #T_c028f_row11_col3, #T_c028f_row11_col4, #T_c028f_row11_col5, #T_c028f_row12_col0, #T_c028f_row12_col1, #T_c028f_row12_col2, #T_c028f_row12_col3, #T_c028f_row12_col4, #T_c028f_row12_col5, #T_c028f_row13_col0, #T_c028f_row13_col1, #T_c028f_row13_col2, #T_c028f_row13_col3, #T_c028f_row13_col4, #T_c028f_row14_col0, #T_c028f_row14_col1, #T_c028f_row14_col2, #T_c028f_row14_col3, #T_c028f_row14_col4, #T_c028f_row14_col5, #T_c028f_row15_col0, #T_c028f_row15_col1, #T_c028f_row15_col2, #T_c028f_row15_col3, #T_c028f_row15_col4, #T_c028f_row15_col5, #T_c028f_row16_col0, #T_c028f_row16_col1, #T_c028f_row16_col2, #T_c028f_row16_col3, #T_c028f_row16_col4, #T_c028f_row16_col5, #T_c028f_row17_col0, #T_c028f_row17_col1, #T_c028f_row17_col2, #T_c028f_row17_col3, #T_c028f_row17_col4 {
#   text-align: center;
# }
# #T_c028f_row13_col5, #T_c028f_row17_col5 {
#   color: crimson;
#   font-weight: bold;
#   text-align: center;
# }
# </style>
# <table id="T_c028f">
#   <caption>ISO 18571 results</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c028f_level0_col0" class="col_heading level0 col0" >Test</th>
#       <th id="T_c028f_level0_col1" class="col_heading level0 col1" >Corridor Score</th>
#       <th id="T_c028f_level0_col2" class="col_heading level0 col2" >Phase Score</th>
#       <th id="T_c028f_level0_col3" class="col_heading level0 col3" >Magnitude Score</th>
#       <th id="T_c028f_level0_col4" class="col_heading level0 col4" >Slope Score</th>
#       <th id="T_c028f_level0_col5" class="col_heading level0 col5" >Overall Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c028f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c028f_row0_col0" class="data row0 col0" >1_01</td>
#       <td id="T_c028f_row0_col1" class="data row0 col1" >0.79</td>
#       <td id="T_c028f_row0_col2" class="data row0 col2" >0.92</td>
#       <td id="T_c028f_row0_col3" class="data row0 col3" >0.90</td>
#       <td id="T_c028f_row0_col4" class="data row0 col4" >0.59</td>
#       <td id="T_c028f_row0_col5" class="data row0 col5" >0.80</td>
#     </tr>
#     <tr>
#       <th id="T_c028f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c028f_row1_col0" class="data row1 col0" >1_02</td>
#       <td id="T_c028f_row1_col1" class="data row1 col1" >0.67</td>
#       <td id="T_c028f_row1_col2" class="data row1 col2" >1.00</td>
#       <td id="T_c028f_row1_col3" class="data row1 col3" >0.68</td>
#       <td id="T_c028f_row1_col4" class="data row1 col4" >0.56</td>
#       <td id="T_c028f_row1_col5" class="data row1 col5" >0.71</td>
#     </tr>
#     <tr>
#       <th id="T_c028f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c028f_row2_col0" class="data row2 col0" >1_03</td>
#       <td id="T_c028f_row2_col1" class="data row2 col1" >0.76</td>
#       <td id="T_c028f_row2_col2" class="data row2 col2" >0.82</td>
#       <td id="T_c028f_row2_col3" class="data row2 col3" >0.89</td>
#       <td id="T_c028f_row2_col4" class="data row2 col4" >0.69</td>
#       <td id="T_c028f_row2_col5" class="data row2 col5" >0.78</td>
#     </tr>
#     <tr>
#       <th id="T_c028f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c028f_row3_col0" class="data row3 col0" >1_04</td>
#       <td id="T_c028f_row3_col1" class="data row3 col1" >0.54</td>
#       <td id="T_c028f_row3_col2" class="data row3 col2" >0.48</td>
#       <td id="T_c028f_row3_col3" class="data row3 col3" >0.78</td>
#       <td id="T_c028f_row3_col4" class="data row3 col4" >0.81</td>
#       <td id="T_c028f_row3_col5" class="data row3 col5" >0.63</td>
#     </tr>
#     <tr>
#       <th id="T_c028f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c028f_row4_col0" class="data row4 col0" >1_05</td>
#       <td id="T_c028f_row4_col1" class="data row4 col1" >0.92</td>
#       <td id="T_c028f_row4_col2" class="data row4 col2" >1.00</td>
#       <td id="T_c028f_row4_col3" class="data row4 col3" >0.96</td>
#       <td id="T_c028f_row4_col4" class="data row4 col4" >0.74</td>
#       <td id="T_c028f_row4_col5" class="data row4 col5" >0.91</td>
#     </tr>
#     <tr>
#       <th id="T_c028f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c028f_row5_col0" class="data row5 col0" >1_06</td>
#       <td id="T_c028f_row5_col1" class="data row5 col1" >0.98</td>
#       <td id="T_c028f_row5_col2" class="data row5 col2" >0.95</td>
#       <td id="T_c028f_row5_col3" class="data row5 col3" >0.96</td>
#       <td id="T_c028f_row5_col4" class="data row5 col4" >0.81</td>
#       <td id="T_c028f_row5_col5" class="data row5 col5" >0.94</td>
#     </tr>
#     <tr>
#       <th id="T_c028f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c028f_row6_col0" class="data row6 col0" >1_07</td>
#       <td id="T_c028f_row6_col1" class="data row6 col1" >0.93</td>
#       <td id="T_c028f_row6_col2" class="data row6 col2" >0.49</td>
#       <td id="T_c028f_row6_col3" class="data row6 col3" >0.76</td>
#       <td id="T_c028f_row6_col4" class="data row6 col4" >0.76</td>
#       <td id="T_c028f_row6_col5" class="data row6 col5" >0.77</td>
#     </tr>
#     <tr>
#       <th id="T_c028f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c028f_row7_col0" class="data row7 col0" >1_08</td>
#       <td id="T_c028f_row7_col1" class="data row7 col1" >0.92</td>
#       <td id="T_c028f_row7_col2" class="data row7 col2" >0.69</td>
#       <td id="T_c028f_row7_col3" class="data row7 col3" >0.86</td>
#       <td id="T_c028f_row7_col4" class="data row7 col4" >0.73</td>
#       <td id="T_c028f_row7_col5" class="data row7 col5" >0.82</td>
#     </tr>
#     <tr>
#       <th id="T_c028f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c028f_row8_col0" class="data row8 col0" >1_09</td>
#       <td id="T_c028f_row8_col1" class="data row8 col1" >0.95</td>
#       <td id="T_c028f_row8_col2" class="data row8 col2" >1.00</td>
#       <td id="T_c028f_row8_col3" class="data row8 col3" >0.97</td>
#       <td id="T_c028f_row8_col4" class="data row8 col4" >0.75</td>
#       <td id="T_c028f_row8_col5" class="data row8 col5" >0.92</td>
#     </tr>
#     <tr>
#       <th id="T_c028f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c028f_row9_col0" class="data row9 col0" >1_10</td>
#       <td id="T_c028f_row9_col1" class="data row9 col1" >0.71</td>
#       <td id="T_c028f_row9_col2" class="data row9 col2" >0.91</td>
#       <td id="T_c028f_row9_col3" class="data row9 col3" >0.68</td>
#       <td id="T_c028f_row9_col4" class="data row9 col4" >0.74</td>
#       <td id="T_c028f_row9_col5" class

# %% [markdown]
# ### 3-pt bending

# %%
fig_ft, axs = plt.subplots(nrows=3, ncols=2,figsize=(7, 6))
i=18
start_time=[26,28,27,28,18,24,25,17,15,26,25,16,17,17,30,20,16,34,15,15.5,23,15,20]

for ax in axs.flat:
    ax.set_ylabel('Force[kN]')
    ax.set_xlabel('Time [ms]');
    if i > 22:
        break;
    ax.set_title('Test {} | M-{} year | {}'.format(Tests[i],Age[i],sp_pos[i]),fontsize=13)
    t=exp.Time[exp[Tests[i]]==max(exp[Tests[i]])].item()
    fail_2p=sim_output[Tests[i]].BONES.strain.time.iloc[sim_output[Tests[i]].BONES.strain.strain[sim_output[Tests[i]].BONES.strain.strain<0.0275].last_valid_index()][0]    
    ax.set_xlim([0,50])
    ax.set_ylim([0,10])
    ax.plot(sim_output[Tests[i]].impactor.Force.time.iloc[:round(t*10)+1],sim_output[Tests[i]].impactor.Force.force.iloc[:round(t*10)+1],**simulation)
    ax.plot(exp.Time,exp[Tests[i]],label='Test',**experiment)
    ax.axvline (x=t,linestyle='--',color='r')
    ax.axvline (x=fail_2p,linestyle='--',color='y')
    i=i+1
fig_ft.delaxes(axs[2,1])
fig_ft.legend(["SAFER11.0","Test","Test stopped","Model plastic-strain >2%"], bbox_to_anchor=(0.95,0.30),fontsize=12);
fig_ft.tight_layout()

# %% [markdown]
# #### ISO18571 objective rating for force-time histories

# %%
# Import objective rating metric library
from objective_rating_metrics.rating import ISO18571

# %%
## Resample data
def resam(xdata,ydata,sT,endtime):
    x = xdata
    y = ydata
    # Interpolate the data to the desired length
    newx = np.arange(sT,endtime,0.1)#10kHz resolution
    newy = np.interp(newx, x, y)
    return np.array(newx).flatten(),np.array(newy).flatten()    

df_res = pd.DataFrame(columns=['Test','Corridor Score', 'Phase Score', 'Magnitude Score', 'Slope Score', 'Overall Score'])
i=18
for test in [ '1_34', '1_37','1_38', '2_06', '2_07b']:
    endT=0
    endT=sim_output[test].BONES.strain.time.iloc[sim_output[test].BONES.strain.strain[sim_output[test].BONES.strain.strain<0.0275].last_valid_index()][0]
    if endT>exp.Time[exp[Tests[i]]==max(exp[Tests[i]])].item():
        endT=exp.Time[exp[Tests[i]]==max(exp[Tests[i]])].item()
    df_rate = pd.DataFrame(columns=['Test','Corridor Score', 'Phase Score', 'Magnitude Score', 'Slope Score', 'Overall Score'])
    if endT>start_time[i]:
        exp_v=exp[test].dropna()
        exp_t=exp.Time[:len(exp_v)].dropna()
        sim_t=np.array(sim_output[test].impactor.Force.time).flatten()
        sim_v=np.array(sim_output[test].impactor.Force.force).flatten()
        r_t,r_v=resam(exp_t,exp_v,start_time[i],endT)
        ref = np.vstack((r_t, r_v)).T
        s_t,s_v=resam(sim_t,sim_v,start_time[i],endT)
        sim = np.vstack((s_t, s_v)).T
        iso_rating = ISO18571(reference_curve=ref, comparison_curve=sim)
        df_rate['Test']=[test]
        df_rate['Corridor Score']=[iso_rating.corridor_rating()]
        df_rate['Phase Score']=[iso_rating.phase_rating()]
        df_rate['Magnitude Score']=[iso_rating.magnitude_rating()]
        df_rate['Slope Score']=[iso_rating.slope_rating()]
        df_rate['Overall Score']=[iso_rating.overall_rating()]
    df_res=pd.concat([df_res,df_rate], ignore_index=True)
    i=i+1

# %%
B1={'width' : 0.5 , 'color':'b','alpha':1, 'edgecolor':'k'}

fig, ax = plt.subplots(figsize=(3, 4))
br1 = np.arange(len(df_res))
ax.bar(br1,df_res['Overall Score'].values,**B1)

plt.xticks(range(len(df_res)), df_res['Test'], rotation=90)
ax.set_ylim([0,1])
ax.set_yticks([0.5,0.58,0.80,0.94,1])
ax.grid(axis='x')
ax.set_title('ISO18571',fontsize=20,fontweight='bold')
fig.tight_layout()
print('Average: {} \nRange: {}-{}'.format(df_res['Overall Score'].mean().round(2),
                                           min(df_res['Overall Score'].round(2)),
                                           max(df_res['Overall Score'].round(2))))

df_res.style.apply(select_col, axis=None).format(precision=2).set_caption("ISO 18571 results").set_table_styles(heading).set_properties(**content)
# Out:
# Average: 0.55
# Range: 0.24-0.78
# <style type="text/css">
# #T_34e4b caption {
#   text-align: center;
#   font-size: 150%;
#   font-weight: bold;
# }
# #T_34e4b_row0_col0, #T_34e4b_row0_col1, #T_34e4b_row0_col2, #T_34e4b_row0_col3, #T_34e4b_row0_col4, #T_34e4b_row0_col5, #T_34e4b_row1_col0, #T_34e4b_row1_col1, #T_34e4b_row1_col2, #T_34e4b_row1_col3, #T_34e4b_row1_col4, #T_34e4b_row1_col5, #T_34e4b_row2_col0, #T_34e4b_row2_col1, #T_34e4b_row2_col2, #T_34e4b_row2_col3, #T_34e4b_row2_col4, #T_34e4b_row3_col0, #T_34e4b_row3_col1, #T_34e4b_row3_col2, #T_34e4b_row3_col3, #T_34e4b_row3_col4, #T_34e4b_row4_col0, #T_34e4b_row4_col1, #T_34e4b_row4_col2, #T_34e4b_row4_col3, #T_34e4b_row4_col4, #T_34e4b_row4_col5 {
#   text-align: center;
# }
# #T_34e4b_row2_col5, #T_34e4b_row3_col5 {
#   color: crimson;
#   font-weight: bold;
#   text-align: center;
# }
# </style>
# <table id="T_34e4b">
#   <caption>ISO 18571 results</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34e4b_level0_col0" class="col_heading level0 col0" >Test</th>
#       <th id="T_34e4b_level0_col1" class="col_heading level0 col1" >Corridor Score</th>
#       <th id="T_34e4b_level0_col2" class="col_heading level0 col2" >Phase Score</th>
#       <th id="T_34e4b_level0_col3" class="col_heading level0 col3" >Magnitude Score</th>
#       <th id="T_34e4b_level0_col4" class="col_heading level0 col4" >Slope Score</th>
#       <th id="T_34e4b_level0_col5" class="col_heading level0 col5" >Overall Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34e4b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_34e4b_row0_col0" class="data row0 col0" >1_34</td>
#       <td id="T_34e4b_row0_col1" class="data row0 col1" >0.72</td>
#       <td id="T_34e4b_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_34e4b_row0_col3" class="data row0 col3" >0.83</td>
#       <td id="T_34e4b_row0_col4" class="data row0 col4" >0.64</td>
#       <td id="T_34e4b_row0_col5" class="data row0 col5" >0.78</td>
#     </tr>
#     <tr>
#       <th id="T_34e4b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_34e4b_row1_col0" class="data row1 col0" >1_37</td>
#       <td id="T_34e4b_row1_col1" class="data row1 col1" >0.65</td>
#       <td id="T_34e4b_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_34e4b_row1_col3" class="data row1 col3" >0.50</td>
#       <td id="T_34e4b_row1_col4" class="data row1 col4" >0.58</td>
#       <td id="T_34e4b_row1_col5" class="data row1 col5" >0.68</td>
#     </tr>
#     <tr>
#       <th id="T_34e4b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_34e4b_row2_col0" class="data row2 col0" >1_38</td>
#       <td id="T_34e4b_row2_col1" class="data row2 col1" >0.47</td>
#       <td id="T_34e4b_row2_col2" class="data row2 col2" >0.01</td>
#       <td id="T_34e4b_row2_col3" class="data row2 col3" >0.00</td>
#       <td id="T_34e4b_row2_col4" class="data row2 col4" >0.23</td>
#       <td id="T_34e4b_row2_col5" class="data row2 col5" >0.24</td>
#     </tr>
#     <tr>
#       <th id="T_34e4b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_34e4b_row3_col0" class="data row3 col0" >2_06</td>
#       <td id="T_34e4b_row3_col1" class="data row3 col1" >0.67</td>
#       <td id="T_34e4b_row3_col2" class="data row3 col2" >0.11</td>
#       <td id="T_34e4b_row3_col3" class="data row3 col3" >0.00</td>
#       <td id="T_34e4b_row3_col4" class="data row3 col4" >0.33</td>
#       <td id="T_34e4b_row3_col5" class="data row3 col5" >0.36</td>
#     </tr>
#     <tr>
#       <th id="T_34e4b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_34e4b_row4_col0" class="data row4 col0" >2_07b</td>
#       <td id="T_34e4b_row4_col1" class="data row4 col1" >0.63</td>
#       <td id="T_34e4b_row4_col2" class="data row4 col2" >0.92</td>
#       <td id="T_34e4b_row4_col3" class="data row4 col3" >0.70</td>
#       <td id="T_34e4b_row4_col4" class="data row4 col4" >0.67</td>
#       <td id="T_34e4b_row4_col5" class="data row4 col5" >0.71</td>
#     </tr>
#   </tbody>
# </table>
