# %% [markdown]
# # Ivarsson et al. (2009): Femur shaft Bending and axial compression

# %% [markdown]
# - Performed by: Yash Niranjan Poojary
# - Reviewed by:
# - Last modified : 31st January 2024
# - SAFER HBM Version: ![Static Badge](https://img.shields.io/badge/SAFER_HBM-11.0-1?style=flat&logoColor=blue&labelColor=whitw&color=blue)
# - LSDYNA version:  `mpp d R12.2.1 `

# %% [markdown]
# ## Experiment by  Ivarsson (2009)
#
# ### Summary:
#
# The simulated outputs are compared to the references from PMHS tests reported by  Ivarsson  <sup>[1]</sup>
# 1. IVARSSON, B. Johan, et al. The tolerance of the femoral shaft in combined axial compression and bending loading. Stapp car crash journal, 2009, 53: 251.
#
# <!-- ![](../_env/setup_ivarsson_femur.PNG)  -->
# ```{figure} ../_env/setup_ivarsson_femur.PNG
# ---
# align: center
# ---
# Setups in testing
# ```

# %% [markdown]
# ## Experiment
# ### Information on the subjects/specimens
# | Test ID | Subject ID | Age (yrs) | Sex |    Loading mode   |
# |:-------:|:----------:|:---------:|:---:|:-----------------:|
# |   1.01  |     373    |     51    |  M  | Combined Loading  |
# |   1.02  |     373    |     51    |  M  | Combined Loading  |
# |   1.03  |     374    |     62    |  M  | Combined Loading  |
# |   1.04  |     374    |     62    |  M  | Combined Loading  |
# |   1.05  |     375    |     62    |  M  | Combined Loading  |
# |   1.06  |     375    |     62    |  M  | Combined Loading  |
# |   1.07  |     376    |     49    |  M  | Combined Loading  |
# |   1.08  |     376    |     49    |  M  | Combined Loading  |
# |   1.09  |     377    |     62    |  M  | Combined Loading  |
# |   1.1   |     378    |     44    |  M  | Combined Loading  |
# |   1.11  |     378    |     44    |  M  | Combined Loading  |
# |   1.12  |     379    |     58    |  M  | Combined Loading  |
# |   1.13  |     379    |     58    |  M  | Combined Loading  |
# |   1.14  |     380    |     65    |  M  | Combined Loading  |
# |   1.15  |     380    |     65    |  M  | Combined Loading  |
# |   1.16  |     381    |     53    |  M  | Combined Loading  |
# |   1.17  |     381    |     53    |  M  | Combined Loading  |
# |   1.30  |     385    |     62    |  M  | Combined Loading  |
# |   1.34  |     390    |     63    |  M  | Bending           |
# |   1.37  |     392    |     45    |  M  | Bending           |
# |   1.38  |     392    |     45    |  M  | Bending           |
# |   2.06  |     327    |     39    |  M  | Bending           |
# |  2.07b  |     362    |     51    |  M  | Bending           |
#
#
#
# ### Loading and Boundary Conditions
# - 23 male specimens tested for axial compression, bending and combined loading.
# - The potting cups are made of PMMA were defined with youngs modulus 3.1 GPa, poissons ratio 0.3 and density $1180 kg/m^3$
# - The linear bearings were defined as rigid parts youngs modulus 70 GPa, poissons ratio 0.34 and density $2700 kg/m^3$
# - A foam material for bending and combined load cases was defined using MAT57 (`*MAT_LOW_DENSITY_FOAM`) material with a nominal stress versus strain curve extracted from the litrture and density 15.6 $kg/m^3$. Two layers of 1 mm belytschko-tsay shell elements were generated as `MAT_NULL_SHELLS` to prevent penetrations.
# - The ends of the femur shaft was aligned with the line connecting the centre of rotation of the potting cups.
# - Each potting cup-holder, with linear bearings, were modelled as a revolute joint.
# - The right cup, cup-holder and linear bearing was allowed to translate in X-direction, other degrees of freedom were
# - restricted. Each of the 23 tests were modelled with associated prescribed displacement from the litrature
# ### Responses recorded
# - force-time  measured at the contact.
# - displacement time of the impactor.
#
# The reference values from the paper were digitalised and are incuded in the notebook
#
# ### Other references
# 2.	Drevon D, Fursa SR, Malcolm AL. Intercoder reliability and validity of WebPlotDigitizer in extracting graphed data. Behavior modification. 2017;41(2):323-39.
# 3.	Svensson, Gustav. ["Finite Element Modelling of Knee Joint and Femur for Future Injury Assessment"](https://odr.chalmers.se/handle/20.500.12380/305815) (2022).
# 4.	Schubert, A., Erlinger, N., Leo, C., Iraeus, J., John, J., & Klug, C. (2021, September). ["Development of a 50th percentile female femur model"](https://www.ircobi.org/wordpress/downloads/irc21/pdf-files/2138.pdf). In IRCOBI conference proceedings (Online).

# %%
import os
import glob
# for data analysis
import pandas as pd
import numpy as np

# %%
 # Libraries for plotting
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
sns.set_style("whitegrid")
sns.set_context("paper", font_scale=1)
experiment = {"linestyle" :'--', "color" : 'k',"alpha" : 0.7}
simulation = {"linestyle" :'-', "color" : 'b',"alpha" : 0.7,"linewidth":2}
# Dataframe formats
def select_col(x):
    mask = x['Overall Score'] <0.5
    df1 =  pd.DataFrame('', index=x.index, columns=x.columns)
    df1.loc[mask,'Overall Score'] = 'color:crimson;font-weight:bold;'
    return df1
heading = [dict(selector="caption",
            props=[("text-align", "center"),
                   ("font-size", "150%"),
                   ("font-weight", "bold")])]
content={'text-align': 'center'}

# %%
Tests=['1_01' , '1_02', '1_03', '1_04', '1_05',
       '1_06', '1_07', '1_08' , '1_09', '1_10',
       '1_11', '1_12', '1_13', '1_14', '1_15',
       '1_16', '1_17' , '1_30', '1_34', '1_37',
       '1_38', '2_06', '2_07b']


figures_dir = "../data/processed/SAFER_11.0/figures/"
processed_data_dir = f"../data/processed/SAFER_11.0"
experiment_dir= "../data/experiment_data/"
binout_path_sim={}
result_output_dir={}

if not os.path.exists(processed_data_dir): 
    os.makedirs(processed_data_dir)
if not os.path.exists(figures_dir): 
    os.makedirs(figures_dir)

for test in Tests:
    binout_path_sim[test] = test
    result_output_dir[test] = os.path.join(processed_data_dir, binout_path_sim[test])
    if not os.path.exists(result_output_dir[test]): 
        os.makedirs(result_output_dir[test])

# %% [markdown]
# ## Postprocessing with dynasaur

# %%
# Import the dynasaur library
from dynasaur.plugins.data_visualization_controller import DataVisualizationController

# %%
# Path to Dynasaur definition files

# Dynasaur object definitions
dynasaur_ids = ["../_env/id-V11.def"]

# Dynasaur calculation definitions
dynasaur_calculation_defs = [ "../_env/post.def", "../_env/strain_calc.def","../../model/SAFER_11.0/postprocessing/01_energy_calculation.def"]
# dynasaur_calculation_defs = [ "../_env/post.def", "../_env/strain_calc.def", "../_env/stress_calc.def"]

# %%
sim_output={}
exp={}
for test in Tests:
    sim_M = DataVisualizationController(calculation_procedure_def_file=dynasaur_calculation_defs,
                                                  object_def_file=dynasaur_ids,
                                                  data_source= binout_path_sim[test] +'/binout*')
    commands = sim_M.get_defined_calculation_procedures()
    print(commands)
    for command in sim_M.get_defined_calculation_procedures():
        sim_M.calculate(command)
    # export post-processed data
    sim_M.write_CSV(result_output_dir[test], filename="Dynasaur_output.csv")
    # Import processed data
    sim_output[test]=pd.read_csv(os.path.join(result_output_dir[test],"Dynasaur_output.csv"), delimiter=';', na_values='-', header = [0,1,2,3])
# Out:
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 0.441300630569458
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.6356198787689209
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 0.4167618751525879
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.2541828155517578
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_01
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_01\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 0.32486987113952637
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.2243189811706543
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 0.37288999557495117
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.23236298561096191
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_02
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_02\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 0.4019777774810791
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.23042678833007812
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 0.34996914863586426
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.22257781028747559
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_03
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_03\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 0.3198728561401367
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.2012021541595459
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 0.47620081901550293
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.2564504146575928
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_04
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_04\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 0.36765265464782715
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.23107099533081055
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 0.3711364269256592
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.24627399444580078
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_05
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_05\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 0.3637058734893799
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.22429776191711426
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 0.416046142578125
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.2681450843811035
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_06
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_06\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 0.35507798194885254
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.25880956649780273
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 0.5332245826721191
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.34740471839904785
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_07
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_07\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 0.38914012908935547
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.23043560981750488
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 0.3796422481536865
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.20664429664611816
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_08
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_08\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 0.3616459369659424
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.21392512321472168
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 0.36154890060424805
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.22261738777160645
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_09
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_09\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 0.5006272792816162
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.3054087162017822
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 0.46143317222595215
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.29886674880981445
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_10
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_10\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 0.562506914138794
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.343106746673584
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 0.5285212993621826
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.2983524799346924
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_11
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_11\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 0.4717247486114502
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.3134644031524658
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 0.4720473289489746
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.29631519317626953
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_12
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_12\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 0.4357624053955078
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.31331825256347656
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 0.5373194217681885
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.2852766513824463
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_13
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_13\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 0.376145601272583
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.2710144519805908
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 0.4292762279510498
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.2446732521057129
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_14
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_14\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 0.38990116119384766
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.24962639808654785
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 0.4012339115142822
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.2603919506072998
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_15
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_15\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 0.3766052722930908
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.23485302925109863
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 0.36885809898376465
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.2297966480255127
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_16
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_16\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 0.5112051963806152
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.3183608055114746
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 0.4843161106109619
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.2846255302429199
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_17
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_17\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 0.45906496047973633
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.2338700294494629
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 0.40033793449401855
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.2501342296600342
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_30
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_30\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 0.369004487991333
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.1904282569885254
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 0.34767889976501465
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.19001150131225586
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_34
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_34\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 0.38387298583984375
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.20203018188476562
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 0.3664882183074951
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.1927509307861328
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_37
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_37\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 0.34732508659362793
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.19991278648376465
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 0.3513777256011963
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.17266297340393066
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\1_38
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\1_38\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 0.34285426139831543
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.2146768569946289
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 0.429577112197876
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.21515727043151855
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\2_06
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\2_06\Dynasaur_output.csv
# [READ DYNASAUR DEF]	read ../_env/post.def
# [READ DYNASAUR DEF]	read ../_env/strain_calc.def
# [READ DYNASAUR DEF]	read ../../model/SAFER_11.0/postprocessing/01_energy_calculation.def
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read ../_env/id-V11.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read rcforc data ...
# [READ BINOUT]	done reading rcforc!
# [READ BINOUT]	read elout data ...
# [READ BINOUT]	elout: initialize stress solid
# [READ BINOUT]	assign stresses for solid elements
# [READ BINOUT]	extract data took : 0.4240915775299072
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.22275781631469727
# [READ BINOUT]	assign strains for solid elements
# [READ BINOUT]	elout: initialize strain solid
# [READ BINOUT]	extract data took : 0.419283390045166
# [READ BINOUT]	calc eigenvalue
# [READ BINOUT]	calc eigenvalues took : 0.21749424934387207
# [READ BINOUT]	done reading elout!
# [READ BINOUT]	read glstat data ...
# [READ BINOUT]	done reading glstat!
# [{'visualization': 'impactor_Force', 'x_label': 'time', 'y_label': 'force'}, {'visualization': 'BONES_strain', 'x_label': 'time', 'y_label': 'strain'}, {'visualization': 'MODEL_Added_Mass', 'x_label': 'time', 'y_label': 'mass'}, {'visualization': 'MODEL_Total_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Internal_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Kinetic_Energy', 'x_label': 'time', 'y_label': 'energy'}, {'visualization': 'MODEL_Hourglass_Energy', 'x_label': 'time', 'y_label': 'energy'}]
# [CALCULATION]	Calculating Visualization: impactor_Force
# [DATA]	read id 2m from channel name: z_force
# c:\Users\yash\Anaconda3\envs\SOT\lib\site-packages\dynasaur\calc\cfc.py:66: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   sampled_array = np.array(sampled_array)
# [CALCULATION]	Calculating Visualization: BONES_strain
# [CALCULATION]	Calculating Visualization: MODEL_Added_Mass
# [DATA]	ENERGY_GLOBAL read from channel name: added_mass
# [CALCULATION]	Calculating Visualization: MODEL_Total_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: total_energy
# [CALCULATION]	Calculating Visualization: MODEL_Internal_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: internal_energy
# [CALCULATION]	Calculating Visualization: MODEL_Kinetic_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: kinetic_energy
# [CALCULATION]	Calculating Visualization: MODEL_Hourglass_Energy
# [DATA]	ENERGY_GLOBAL read from channel name: hourglass_energy
# [CALCULATION]	DATA VISUALIZATION writing csv to ../data/processed/SAFER_11.0\2_07b
# [CALCULATION]	DATA VISUALIZATION done writing csv to ../data/processed/SAFER_11.0\2_07b\Dynasaur_output.csv

# %%
# Import experimental data
exp=pd.read_csv(os.path.join(experiment_dir,'Ivarsson_et_al_2009_impactor_force.csv'.format(test)),delimiter=';',header=[0])
exp_axl=pd.read_csv(os.path.join(experiment_dir,'Ivarsson_et_al_2009_axial_force.csv'.format(test)),delimiter=';',header=[0])

# %% [markdown]
# ### Combined loading
# #### Posterior-Anterior tests

# %%
Age=['51' , '51', '62', '62', '62','62', '49', '49', '62', '44','44', '58' , '58', '65', '65','53', '53', '62', '63', '45','45', '39', '51']
sp_pos=['PA' , 'PA', 'PA', 'PA', 'AP','PA', 'PA', 'AP', 'AP', 'PA','PA', 'AP' , 'AP', 'AP', 'PA','AP', 'AP', 'PA', 'AP', 'AP','PA', 'AP', 'PA']
start_time=[26,28,27,28,18,24,25,17,15,26,25,16,17,17,30,20,16,34,17,17,24,17,22]

# %%
PA_tests=[0,1,2,3,5,6,9,10,14,17,20,22]
fig_ft, axs = plt.subplots(nrows=4, ncols=3,figsize=(10, 9))
i=0
for ax in axs.flat:
    ax.set_ylabel('Force[kN]')
    ax.set_xlabel('Time [ms]');
    if PA_tests[i] > 17:
        fig_ft.delaxes(ax)
    ax.set_title('Test {} | AF= {:.1f} kN | M-{} year'.format(Tests[PA_tests[i]],max((exp_axl[Tests[PA_tests[i]]])),Age[PA_tests[i]]), weight='bold')
    fail_2p=sim_output[Tests[PA_tests[i]]].BONES.strain.time.iloc[sim_output[Tests[PA_tests[i]]].BONES.strain.strain[sim_output[Tests[PA_tests[i]]].BONES.strain.strain<0.0277].last_valid_index()][0]
    t=exp.Time[exp[Tests[PA_tests[i]]]==max(exp[Tests[PA_tests[i]]])].item()
    ax.set_xlim([0,50])
    ax.set_ylim([0,10])
    ax.plot(sim_output[Tests[PA_tests[i]]].impactor.Force.time.iloc[:round(t)+1],sim_output[Tests[PA_tests[i]]].impactor.Force.force.iloc[:round(t)+1],**simulation)
    ax.plot(exp.Time,exp[Tests[PA_tests[i]]],label='Test',**experiment)
    ax.axvline (x=t,linestyle='--',color='r')
    ax.axvline (x=fail_2p,linestyle='--',color='y')
    i=i+1
fig_ft.legend(["SAFER11.0","Test","Test stopped","Model plastic-strain >2%"], bbox_to_anchor=(0.8,0.2),ncols=2,fontsize=12);
fig_ft.text(0.6,0.1,'* AF: Applied axial force ', style='italic',color='grey')
fig_ft.tight_layout()

# %% [markdown]
# #### Anterior-Posterior tests

# %%
AP_tests=[4,7,8,11,12,13,15,16,18,19,21]
fig_ft, axs = plt.subplots(nrows=3, ncols=3,figsize=(10, 7))
i=0
for ax in axs.flat:
    ax.set_ylabel('Force[kN]')
    ax.set_xlabel('Time [ms]');
    if AP_tests[i] > 17:
        fig_ft.delaxes(ax)
    ax.set_title('Test {} | AF= {:.1f} kN | M-{} year'.format(Tests[AP_tests[i]],max((exp_axl[Tests[AP_tests[i]]])),Age[AP_tests[i]]), weight='bold')
    fail_2p=sim_output[Tests[AP_tests[i]]].BONES.strain.time.iloc[sim_output[Tests[AP_tests[i]]].BONES.strain.strain[sim_output[Tests[AP_tests[i]]].BONES.strain.strain<0.0277].last_valid_index()][0]
    t=exp.Time[exp[Tests[AP_tests[i]]]==max(exp[Tests[AP_tests[i]]])].item()
    ax.set_xlim([0,50])
    ax.set_ylim([0,10])
    ax.plot(sim_output[Tests[AP_tests[i]]].impactor.Force.time.iloc[:round(t)+1],sim_output[Tests[AP_tests[i]]].impactor.Force.force.iloc[:round(t)+1],**simulation)
    ax.plot(exp.Time,exp[Tests[AP_tests[i]]],label='Test',**experiment)
    ax.axvline (x=t,linestyle='--',color='r')
    ax.axvline (x=fail_2p,linestyle='--',color='y')
    i=i+1
fig_ft.legend(["SAFER11.0","Test","Test stopped","Model plastic-strain >2%"], bbox_to_anchor=(1,0.3),ncols=1,fontsize=12);
fig_ft.text(0.7,0.1,'* AF: Applied axial force ', style='italic',color='grey')
fig_ft.tight_layout()

# %% [markdown]
# ### Energy plots

# %%
fig_eny, axs = plt.subplots(nrows=5, ncols=4,figsize=(10,10))
i=0
for ax in axs.flat:
    if i > 17:
        break;
    ax.plot(sim_output[Tests[i]].MODEL.Internal_Energy.time,sim_output[Tests[i]].MODEL.Internal_Energy.energy,linewidth=2)
    ax.plot(sim_output[Tests[i]].MODEL.Kinetic_Energy.time,sim_output[Tests[i]].MODEL.Kinetic_Energy.energy,linestyle='--',alpha=0.7)
    ax.plot(sim_output[Tests[i]].MODEL.Total_Energy.time,sim_output[Tests[i]].MODEL.Total_Energy.energy,linestyle='--',alpha=0.7)
    ax.plot(sim_output[Tests[i]].MODEL.Hourglass_Energy.time,sim_output[Tests[i]].MODEL.Hourglass_Energy.energy,linewidth=2)
    ax.set(title="Test {}".format(Tests[i]),xlabel='Time [ms]',ylabel='Energy [J]')
    i=i+1
fig_eny.delaxes(axs[4,2])
fig_eny.delaxes(axs[4,3])

fig_eny.legend(["Internal energy","Kinetic Energy","Total Energy","Hourglass energy"], bbox_to_anchor=(0.9,0.15),ncol=2);
fig_eny.tight_layout()

# %% [markdown]
# #### ISO18571 objective rating for force-time histories

# %%
# Import objective rating metric library
from objective_rating_metrics.rating import ISO18571

# %%
## Resample data
def resam(xdata,ydata,sT,endtime):
    x = xdata
    y = ydata
    # Interpolate the data to the desired length
    newx = np.arange(sT,endtime,0.1)#10kHz resolution
    newy = np.interp(newx, x, y)
    return np.array(newx).flatten(),np.array(newy).flatten()    
df_res = pd.DataFrame(columns=['Test','Corridor Score', 'Phase Score', 'Magnitude Score', 'Slope Score', 'Overall Score'])
i=0
for test in Tests:
    endT=0
    if test=='1_34':
        break;
    endT=sim_output[test].BONES.strain.time.iloc[sim_output[test].BONES.strain.strain[sim_output[test].BONES.strain.strain<0.0277].last_valid_index()][0]
    if endT>exp.Time[exp[Tests[i]]==max(exp[Tests[i]])].item():
        endT=exp.Time[exp[Tests[i]]==max(exp[Tests[i]])].item()
    df_rate = pd.DataFrame(columns=['Test','Corridor Score', 'Phase Score', 'Magnitude Score', 'Slope Score', 'Overall Score'])
    if endT>start_time[i]:
        exp_v=exp[test].dropna()
        exp_t=exp.Time[:len(exp_v)].dropna()
        sim_t=np.array(sim_output[test].impactor.Force.time).flatten()
        sim_v=np.array(sim_output[test].impactor.Force.force).flatten()
        r_t,r_v=resam(exp_t,exp_v,start_time[i],endT)
        ref = np.vstack((r_t, r_v)).T
        s_t,s_v=resam(sim_t,sim_v,start_time[i],endT)
        sim = np.vstack((s_t, s_v)).T
        iso_rating = ISO18571(reference_curve=ref, comparison_curve=sim)
        df_rate['Test']=[test]
        df_rate['Corridor Score']=[iso_rating.corridor_rating()]
        df_rate['Phase Score']=[iso_rating.phase_rating()]
        df_rate['Magnitude Score']=[iso_rating.magnitude_rating()]
        df_rate['Slope Score']=[iso_rating.slope_rating()]
        df_rate['Overall Score']=[iso_rating.overall_rating()]
    df_res=pd.concat([df_res,df_rate], ignore_index=True)
    i=i+1

# %% [markdown]
# ##### Posterior-Anterior tests

# %%
df_BC=df_res.loc[df_res.index[[0,1,2,3,5,6,9,10,14,17]]]
B1={'width' : 0.5 , 'color':'b','alpha':1, 'edgecolor':'k'}
fig, ax = plt.subplots(figsize=(5, 3))
br1 = np.arange(len(df_BC))
ax.bar(br1,df_BC['Overall Score'].values,**B1)
plt.xticks(range(len(df_BC)), df_BC['Test'], rotation=0)
ax.set_ylim([0,1])
ax.set_yticks([0.5,0.58,0.80,0.94,1])
ax.grid(axis='x')
ax.set_title('ISO18571',fontsize=20,fontweight='bold')

print('Average: {} \nRange: {}-{}'.format(df_BC['Overall Score'].mean().round(2),
                                           min(df_BC['Overall Score'].round(2)),
                                           max(df_BC['Overall Score'].round(2))))

df_BC.style.apply(select_col, axis=None).format(precision=2).set_caption("ISO 18571 results").set_table_styles(heading).set_properties(**content)
# Out:
# Average: 0.79
# Range: 0.51-0.9
# <style type="text/css">
# #T_0a147 caption {
#   text-align: center;
#   font-size: 150%;
#   font-weight: bold;
# }
# #T_0a147_row0_col0, #T_0a147_row0_col1, #T_0a147_row0_col2, #T_0a147_row0_col3, #T_0a147_row0_col4, #T_0a147_row0_col5, #T_0a147_row1_col0, #T_0a147_row1_col1, #T_0a147_row1_col2, #T_0a147_row1_col3, #T_0a147_row1_col4, #T_0a147_row1_col5, #T_0a147_row2_col0, #T_0a147_row2_col1, #T_0a147_row2_col2, #T_0a147_row2_col3, #T_0a147_row2_col4, #T_0a147_row2_col5, #T_0a147_row3_col0, #T_0a147_row3_col1, #T_0a147_row3_col2, #T_0a147_row3_col3, #T_0a147_row3_col4, #T_0a147_row3_col5, #T_0a147_row4_col0, #T_0a147_row4_col1, #T_0a147_row4_col2, #T_0a147_row4_col3, #T_0a147_row4_col4, #T_0a147_row4_col5, #T_0a147_row5_col0, #T_0a147_row5_col1, #T_0a147_row5_col2, #T_0a147_row5_col3, #T_0a147_row5_col4, #T_0a147_row5_col5, #T_0a147_row6_col0, #T_0a147_row6_col1, #T_0a147_row6_col2, #T_0a147_row6_col3, #T_0a147_row6_col4, #T_0a147_row6_col5, #T_0a147_row7_col0, #T_0a147_row7_col1, #T_0a147_row7_col2, #T_0a147_row7_col3, #T_0a147_row7_col4, #T_0a147_row7_col5, #T_0a147_row8_col0, #T_0a147_row8_col1, #T_0a147_row8_col2, #T_0a147_row8_col3, #T_0a147_row8_col4, #T_0a147_row8_col5, #T_0a147_row9_col0, #T_0a147_row9_col1, #T_0a147_row9_col2, #T_0a147_row9_col3, #T_0a147_row9_col4, #T_0a147_row9_col5 {
#   text-align: center;
# }
# </style>
# <table id="T_0a147">
#   <caption>ISO 18571 results</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0a147_level0_col0" class="col_heading level0 col0" >Test</th>
#       <th id="T_0a147_level0_col1" class="col_heading level0 col1" >Corridor Score</th>
#       <th id="T_0a147_level0_col2" class="col_heading level0 col2" >Phase Score</th>
#       <th id="T_0a147_level0_col3" class="col_heading level0 col3" >Magnitude Score</th>
#       <th id="T_0a147_level0_col4" class="col_heading level0 col4" >Slope Score</th>
#       <th id="T_0a147_level0_col5" class="col_heading level0 col5" >Overall Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a147_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0a147_row0_col0" class="data row0 col0" >1_01</td>
#       <td id="T_0a147_row0_col1" class="data row0 col1" >0.86</td>
#       <td id="T_0a147_row0_col2" class="data row0 col2" >0.93</td>
#       <td id="T_0a147_row0_col3" class="data row0 col3" >0.87</td>
#       <td id="T_0a147_row0_col4" class="data row0 col4" >0.60</td>
#       <td id="T_0a147_row0_col5" class="data row0 col5" >0.82</td>
#     </tr>
#     <tr>
#       <th id="T_0a147_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0a147_row1_col0" class="data row1 col0" >1_02</td>
#       <td id="T_0a147_row1_col1" class="data row1 col1" >0.77</td>
#       <td id="T_0a147_row1_col2" class="data row1 col2" >1.00</td>
#       <td id="T_0a147_row1_col3" class="data row1 col3" >0.77</td>
#       <td id="T_0a147_row1_col4" class="data row1 col4" >0.56</td>
#       <td id="T_0a147_row1_col5" class="data row1 col5" >0.77</td>
#     </tr>
#     <tr>
#       <th id="T_0a147_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0a147_row2_col0" class="data row2 col0" >1_03</td>
#       <td id="T_0a147_row2_col1" class="data row2 col1" >0.87</td>
#       <td id="T_0a147_row2_col2" class="data row2 col2" >0.06</td>
#       <td id="T_0a147_row2_col3" class="data row2 col3" >0.55</td>
#       <td id="T_0a147_row2_col4" class="data row2 col4" >0.62</td>
#       <td id="T_0a147_row2_col5" class="data row2 col5" >0.59</td>
#     </tr>
#     <tr>
#       <th id="T_0a147_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0a147_row3_col0" class="data row3 col0" >1_04</td>
#       <td id="T_0a147_row3_col1" class="data row3 col1" >0.92</td>
#       <td id="T_0a147_row3_col2" class="data row3 col2" >0.56</td>
#       <td id="T_0a147_row3_col3" class="data row3 col3" >0.95</td>
#       <td id="T_0a147_row3_col4" class="data row3 col4" >0.85</td>
#       <td id="T_0a147_row3_col5" class="data row3 col5" >0.84</td>
#     </tr>
#     <tr>
#       <th id="T_0a147_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_0a147_row4_col0" class="data row4 col0" >1_06</td>
#       <td id="T_0a147_row4_col1" class="data row4 col1" >0.98</td>
#       <td id="T_0a147_row4_col2" class="data row4 col2" >0.70</td>
#       <td id="T_0a147_row4_col3" class="data row4 col3" >0.95</td>
#       <td id="T_0a147_row4_col4" class="data row4 col4" >0.81</td>
#       <td id="T_0a147_row4_col5" class="data row4 col5" >0.88</td>
#     </tr>
#     <tr>
#       <th id="T_0a147_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_0a147_row5_col0" class="data row5 col0" >1_07</td>
#       <td id="T_0a147_row5_col1" class="data row5 col1" >0.91</td>
#       <td id="T_0a147_row5_col2" class="data row5 col2" >0.79</td>
#       <td id="T_0a147_row5_col3" class="data row5 col3" >0.86</td>
#       <td id="T_0a147_row5_col4" class="data row5 col4" >0.77</td>
#       <td id="T_0a147_row5_col5" class="data row5 col5" >0.85</td>
#     </tr>
#     <tr>
#       <th id="T_0a147_level0_row6" class="row_heading level0 row6" >9</th>
#       <td id="T_0a147_row6_col0" class="data row6 col0" >1_10</td>
#       <td id="T_0a147_row6_col1" class="data row6 col1" >0.86</td>
#       <td id="T_0a147_row6_col2" class="data row6 col2" >0.80</td>
#       <td id="T_0a147_row6_col3" class="data row6 col3" >0.83</td>
#       <td id="T_0a147_row6_col4" class="data row6 col4" >0.81</td>
#       <td id="T_0a147_row6_col5" class="data row6 col5" >0.83</td>
#     </tr>
#     <tr>
#       <th id="T_0a147_level0_row7" class="row_heading level0 row7" >10</th>
#       <td id="T_0a147_row7_col0" class="data row7 col0" >1_11</td>
#       <td id="T_0a147_row7_col1" class="data row7 col1" >0.84</td>
#       <td id="T_0a147_row7_col2" class="data row7 col2" >0.80</td>
#       <td id="T_0a147_row7_col3" class="data row7 col3" >0.97</td>
#       <td id="T_0a147_row7_col4" class="data row7 col4" >0.85</td>
#       <td id="T_0a147_row7_col5" class="data row7 col5" >0.86</td>
#     </tr>
#     <tr>
#       <th id="T_0a147_level0_row8" class="row_heading level0 row8" >14</th>
#       <td id="T_0a147_row8_col0" class="data row8 col0" >1_15</td>
#       <td id="T_0a147_row8_col1" class="data row8 col1" >0.95</td>
#       <td id="T_0a147_row8_col2" class="data row8 col2" >0.83</td>
#       <td id="T_0a147_row8_col3" class="data row8 col3" >0.96</td>
#       <td id="T_0a147_row8_col4" class="data row8 col4" >0.80</td>
#       <td id="T_0a147_row8_col5" class="data row8 col5" >0.90</td>
#     </tr>
#     <tr>
#       <th id="T_0a147_level0_row9" class="row_heading level0 row9" >17</th>
#       <td id="T_0a147_row9_col0" class="data row9 col0" >1_30</td>
#       <td id="T_0a147_row9_col1" class="data row9 col1" >0.85</td>
#       <td id="T_0a147_row9_col2" class="data row9 col2" >0.19</td>
#       <td id="T_0a147_row9_col3" class="data row9 col3" >0.00</td>
#       <td id="T_0a147_row9_col4" class="data row9 col4" >0.67</td>
#       <td id="T_0a147_row9_col5" class="data row9 col5" >0.51</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### Anterior-Posterior tests

# %%
df_BC=df_res.loc[df_res.index[[4,7,8,11,12,13,15,16]]]
fig, ax = plt.subplots(figsize=(5, 3))
br1 = np.arange(len(df_BC))
ax.bar(br1,df_BC['Overall Score'].values,**B1)
plt.xticks(range(len(df_BC)), df_BC['Test'], rotation=0)
ax.set_ylim([0,1])
ax.set_yticks([0.5,0.58,0.80,0.94,1])
ax.grid(axis='x')
ax.set_title('ISO18571',fontsize=20,fontweight='bold')

print('Average: {} \nRange: {}-{}'.format(df_BC['Overall Score'].mean().round(2),
                                           min(df_BC['Overall Score'].round(2)),
                                           max(df_BC['Overall Score'].round(2))))

df_BC.style.apply(select_col, axis=None).format(precision=2).set_caption("ISO 18571 results").set_table_styles(heading).set_properties(**content)
# Out:
# Average: 0.74
# Range: 0.3-0.9
# <style type="text/css">
# #T_3cb89 caption {
#   text-align: center;
#   font-size: 150%;
#   font-weight: bold;
# }
# #T_3cb89_row0_col0, #T_3cb89_row0_col1, #T_3cb89_row0_col2, #T_3cb89_row0_col3, #T_3cb89_row0_col4, #T_3cb89_row0_col5, #T_3cb89_row1_col0, #T_3cb89_row1_col1, #T_3cb89_row1_col2, #T_3cb89_row1_col3, #T_3cb89_row1_col4, #T_3cb89_row1_col5, #T_3cb89_row2_col0, #T_3cb89_row2_col1, #T_3cb89_row2_col2, #T_3cb89_row2_col3, #T_3cb89_row2_col4, #T_3cb89_row2_col5, #T_3cb89_row3_col0, #T_3cb89_row3_col1, #T_3cb89_row3_col2, #T_3cb89_row3_col3, #T_3cb89_row3_col4, #T_3cb89_row3_col5, #T_3cb89_row4_col0, #T_3cb89_row4_col1, #T_3cb89_row4_col2, #T_3cb89_row4_col3, #T_3cb89_row4_col4, #T_3cb89_row4_col5, #T_3cb89_row5_col0, #T_3cb89_row5_col1, #T_3cb89_row5_col2, #T_3cb89_row5_col3, #T_3cb89_row5_col4, #T_3cb89_row6_col0, #T_3cb89_row6_col1, #T_3cb89_row6_col2, #T_3cb89_row6_col3, #T_3cb89_row6_col4, #T_3cb89_row6_col5, #T_3cb89_row7_col0, #T_3cb89_row7_col1, #T_3cb89_row7_col2, #T_3cb89_row7_col3, #T_3cb89_row7_col4 {
#   text-align: center;
# }
# #T_3cb89_row5_col5, #T_3cb89_row7_col5 {
#   color: crimson;
#   font-weight: bold;
#   text-align: center;
# }
# </style>
# <table id="T_3cb89">
#   <caption>ISO 18571 results</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3cb89_level0_col0" class="col_heading level0 col0" >Test</th>
#       <th id="T_3cb89_level0_col1" class="col_heading level0 col1" >Corridor Score</th>
#       <th id="T_3cb89_level0_col2" class="col_heading level0 col2" >Phase Score</th>
#       <th id="T_3cb89_level0_col3" class="col_heading level0 col3" >Magnitude Score</th>
#       <th id="T_3cb89_level0_col4" class="col_heading level0 col4" >Slope Score</th>
#       <th id="T_3cb89_level0_col5" class="col_heading level0 col5" >Overall Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3cb89_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_3cb89_row0_col0" class="data row0 col0" >1_05</td>
#       <td id="T_3cb89_row0_col1" class="data row0 col1" >0.88</td>
#       <td id="T_3cb89_row0_col2" class="data row0 col2" >1.00</td>
#       <td id="T_3cb89_row0_col3" class="data row0 col3" >0.95</td>
#       <td id="T_3cb89_row0_col4" class="data row0 col4" >0.73</td>
#       <td id="T_3cb89_row0_col5" class="data row0 col5" >0.89</td>
#     </tr>
#     <tr>
#       <th id="T_3cb89_level0_row1" class="row_heading level0 row1" >7</th>
#       <td id="T_3cb89_row1_col0" class="data row1 col0" >1_08</td>
#       <td id="T_3cb89_row1_col1" class="data row1 col1" >0.92</td>
#       <td id="T_3cb89_row1_col2" class="data row1 col2" >0.45</td>
#       <td id="T_3cb89_row1_col3" class="data row1 col3" >0.90</td>
#       <td id="T_3cb89_row1_col4" class="data row1 col4" >0.77</td>
#       <td id="T_3cb89_row1_col5" class="data row1 col5" >0.79</td>
#     </tr>
#     <tr>
#       <th id="T_3cb89_level0_row2" class="row_heading level0 row2" >8</th>
#       <td id="T_3cb89_row2_col0" class="data row2 col0" >1_09</td>
#       <td id="T_3cb89_row2_col1" class="data row2 col1" >0.90</td>
#       <td id="T_3cb89_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_3cb89_row2_col3" class="data row2 col3" >0.97</td>
#       <td id="T_3cb89_row2_col4" class="data row2 col4" >0.74</td>
#       <td id="T_3cb89_row2_col5" class="data row2 col5" >0.90</td>
#     </tr>
#     <tr>
#       <th id="T_3cb89_level0_row3" class="row_heading level0 row3" >11</th>
#       <td id="T_3cb89_row3_col0" class="data row3 col0" >1_12</td>
#       <td id="T_3cb89_row3_col1" class="data row3 col1" >0.89</td>
#       <td id="T_3cb89_row3_col2" class="data row3 col2" >1.00</td>
#       <td id="T_3cb89_row3_col3" class="data row3 col3" >0.94</td>
#       <td id="T_3cb89_row3_col4" class="data row3 col4" >0.70</td>
#       <td id="T_3cb89_row3_col5" class="data row3 col5" >0.88</td>
#     </tr>
#     <tr>
#       <th id="T_3cb89_level0_row4" class="row_heading level0 row4" >12</th>
#       <td id="T_3cb89_row4_col0" class="data row4 col0" >1_13</td>
#       <td id="T_3cb89_row4_col1" class="data row4 col1" >0.85</td>
#       <td id="T_3cb89_row4_col2" class="data row4 col2" >1.00</td>
#       <td id="T_3cb89_row4_col3" class="data row4 col3" >0.83</td>
#       <td id="T_3cb89_row4_col4" class="data row4 col4" >0.69</td>
#       <td id="T_3cb89_row4_col5" class="data row4 col5" >0.84</td>
#     </tr>
#     <tr>
#       <th id="T_3cb89_level0_row5" class="row_heading level0 row5" >13</th>
#       <td id="T_3cb89_row5_col0" class="data row5 col0" >1_14</td>
#       <td id="T_3cb89_row5_col1" class="data row5 col1" >0.53</td>
#       <td id="T_3cb89_row5_col2" class="data row5 col2" >0.00</td>
#       <td id="T_3cb89_row5_col3" class="data row5 col3" >0.75</td>
#       <td id="T_3cb89_row5_col4" class="data row5 col4" >0.61</td>
#       <td id="T_3cb89_row5_col5" class="data row5 col5" >0.48</td>
#     </tr>
#     <tr>
#       <th id="T_3cb89_level0_row6" class="row_heading level0 row6" >15</th>
#       <td id="T_3cb89_row6_col0" class="data row6 col0" >1_16</td>
#       <td id="T_3cb89_row6_col1" class="data row6 col1" >0.90</td>
#       <td id="T_3cb89_row6_col2" class="data row6 col2" >0.50</td>
#       <td id="T_3cb89_row6_col3" class="data row6 col3" >0.95</td>
#       <td id="T_3cb89_row6_col4" class="data row6 col4" >0.82</td>
#       <td id="T_3cb89_row6_col5" class="data row6 col5" >0.81</td>
#     </tr>
#     <tr>
#       <th id="T_3cb89_level0_row7" class="row_heading level0 row7" >16</th>
#       <td id="T_3cb89_row7_col0" class="data row7 col0" >1_17</td>
#       <td id="T_3cb89_row7_col1" class="data row7 col1" >0.54</td>
#       <td id="T_3cb89_row7_col2" class="data row7 col2" >0.00</td>
#       <td id="T_3cb89_row7_col3" class="data row7 col3" >0.00</td>
#       <td id="T_3cb89_row7_col4" class="data row7 col4" >0.44</td>
#       <td id="T_3cb89_row7_col5" class="data row7 col5" >0.30</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 3-pt bending
# #### Posterior-Anterior tests

# %%
PA_tests=[20,22]
fig_ft, axs = plt.subplots(nrows=1, ncols=2,figsize=(7, 3))
i=0
for ax in axs.flat:
    ax.set_ylabel('Force[kN]')
    ax.set_xlabel('Time [ms]');
    if PA_tests[i] > 22:
        fig_ft.delaxes(ax)
    ax.set_title('Test {} | AF= {:.1f} kN | M-{} year'.format(Tests[PA_tests[i]],max((exp_axl[Tests[PA_tests[i]]])),Age[PA_tests[i]]), weight='bold')
    fail_2p=sim_output[Tests[PA_tests[i]]].BONES.strain.time.iloc[sim_output[Tests[PA_tests[i]]].BONES.strain.strain[sim_output[Tests[PA_tests[i]]].BONES.strain.strain<0.0277].last_valid_index()][0]
    t=exp.Time[exp[Tests[PA_tests[i]]]==max(exp[Tests[PA_tests[i]]])].item()
    ax.set_xlim([0,50])
    ax.set_ylim([0,10])
    ax.plot(sim_output[Tests[PA_tests[i]]].impactor.Force.time.iloc[:round(t)+1],sim_output[Tests[PA_tests[i]]].impactor.Force.force.iloc[:round(t)+1],**simulation)
    ax.plot(exp.Time,exp[Tests[PA_tests[i]]],label='Test',**experiment)
    ax.axvline (x=t,linestyle='--',color='r')
    ax.axvline (x=fail_2p,linestyle='--',color='y')
    i=i+1
fig_ft.legend(["SAFER11.0","Test","Test stopped","Model plastic-strain >2%"], bbox_to_anchor=(0.7,0),ncols=2,fontsize=12);
fig_ft.text(0.6,0,'* AF: Applied axial force ', style='italic',color='grey')
fig_ft.tight_layout()

# %% [markdown]
# #### Anterior-Posterior tests

# %%
AP_tests=[18,19,21]
fig_ft, axs = plt.subplots(nrows=1, ncols=3,figsize=(10, 3))
i=0
for ax in axs.flat:
    ax.set_ylabel('Force[kN]')
    ax.set_xlabel('Time [ms]');
    if AP_tests[i] > 22:
        fig_ft.delaxes(ax)
    ax.set_title('Test {} | AF= {:.1f} kN | M-{} year'.format(Tests[AP_tests[i]],max((exp_axl[Tests[AP_tests[i]]])),Age[AP_tests[i]]), weight='bold')
    fail_2p=sim_output[Tests[AP_tests[i]]].BONES.strain.time.iloc[sim_output[Tests[AP_tests[i]]].BONES.strain.strain[sim_output[Tests[AP_tests[i]]].BONES.strain.strain<0.0277].last_valid_index()][0]
    t=exp.Time[exp[Tests[AP_tests[i]]]==max(exp[Tests[AP_tests[i]]])].item()
    ax.set_xlim([0,50])
    ax.set_ylim([0,10])
    ax.plot(sim_output[Tests[AP_tests[i]]].impactor.Force.time.iloc[:round(t)+1],sim_output[Tests[AP_tests[i]]].impactor.Force.force.iloc[:round(t)+1],**simulation)
    ax.plot(exp.Time,exp[Tests[AP_tests[i]]],label='Test',**experiment)
    ax.axvline (x=t,linestyle='--',color='r')
    ax.axvline (x=fail_2p,linestyle='--',color='y')
    i=i+1
fig_ft.legend(["SAFER11.0","Test","Test stopped","Model plastic-strain >2%"], bbox_to_anchor=(0.6,0),ncols=2,fontsize=12);
fig_ft.text(0.7,0,'* AF: Applied axial force ', style='italic',color='grey')
fig_ft.tight_layout()

# %% [markdown]
# ### Energy plots

# %%
fig_eny, axs = plt.subplots(nrows=2, ncols=3,figsize=(10,5))
i=18
for ax in axs.flat:
    if i > 22:
        break;
    ax.plot(sim_output[Tests[i]].MODEL.Internal_Energy.time,sim_output[Tests[i]].MODEL.Internal_Energy.energy,linewidth=2)
    ax.plot(sim_output[Tests[i]].MODEL.Kinetic_Energy.time,sim_output[Tests[i]].MODEL.Kinetic_Energy.energy,linestyle='--',alpha=0.7)
    ax.plot(sim_output[Tests[i]].MODEL.Total_Energy.time,sim_output[Tests[i]].MODEL.Total_Energy.energy,linestyle='--',alpha=0.7)
    ax.plot(sim_output[Tests[i]].MODEL.Hourglass_Energy.time,sim_output[Tests[i]].MODEL.Hourglass_Energy.energy,linewidth=2)
    ax.set(title="Test {}".format(Tests[i]),xlabel='Time [ms]',ylabel='Energy [J]')
    i=i+1
fig_eny.delaxes(axs[1,2])

fig_eny.legend(["Internal energy","Kinetic Energy","Total Energy","Hourglass energy"], bbox_to_anchor=(0.98,0.35),ncol=1);
fig_eny.tight_layout()

# %% [markdown]
# #### ISO18571 objective rating for force-time histories

# %%
# Import objective rating metric library
from objective_rating_metrics.rating import ISO18571

# %%
## Resample data
def resam(xdata,ydata,sT,endtime):
    x = xdata
    y = ydata
    # Interpolate the data to the desired length
    newx = np.arange(sT,endtime,0.1)#10kHz resolution
    newy = np.interp(newx, x, y)
    return np.array(newx).flatten(),np.array(newy).flatten()    

df_res = pd.DataFrame(columns=['Test','Corridor Score', 'Phase Score', 'Magnitude Score', 'Slope Score', 'Overall Score'])
i=18
for test in [ '1_34', '1_37','1_38', '2_06', '2_07b']:
    endT=0
    endT=sim_output[test].BONES.strain.time.iloc[sim_output[test].BONES.strain.strain[sim_output[test].BONES.strain.strain<0.0275].last_valid_index()][0]
    if endT>exp.Time[exp[Tests[i]]==max(exp[Tests[i]])].item():
        endT=exp.Time[exp[Tests[i]]==max(exp[Tests[i]])].item()
    df_rate = pd.DataFrame(columns=['Test','Corridor Score', 'Phase Score', 'Magnitude Score', 'Slope Score', 'Overall Score'])
    if endT>start_time[i]:
        exp_v=exp[test].dropna()
        exp_t=exp.Time[:len(exp_v)].dropna()
        sim_t=np.array(sim_output[test].impactor.Force.time).flatten()
        sim_v=np.array(sim_output[test].impactor.Force.force).flatten()
        r_t,r_v=resam(exp_t,exp_v,start_time[i],endT)
        ref = np.vstack((r_t, r_v)).T
        s_t,s_v=resam(sim_t,sim_v,start_time[i],endT)
        sim = np.vstack((s_t, s_v)).T
        iso_rating = ISO18571(reference_curve=ref, comparison_curve=sim)
        df_rate['Test']=[test]
        df_rate['Corridor Score']=[iso_rating.corridor_rating()]
        df_rate['Phase Score']=[iso_rating.phase_rating()]
        df_rate['Magnitude Score']=[iso_rating.magnitude_rating()]
        df_rate['Slope Score']=[iso_rating.slope_rating()]
        df_rate['Overall Score']=[iso_rating.overall_rating()]
    df_res=pd.concat([df_res,df_rate], ignore_index=True)
    i=i+1

# %% [markdown]
# ##### Posterior-Anterior tests

# %%
df_BC=df_res.loc[df_res.index[[2,4]]]
fig, ax = plt.subplots(figsize=(2, 3))
br1 = np.arange(len(df_BC))
ax.bar(br1,df_BC['Overall Score'].values,**B1)
plt.xticks(range(len(df_BC)), df_BC['Test'], rotation=0)
ax.set_ylim([0,1])
ax.set_yticks([0.5,0.58,0.80,0.94,1])
ax.grid(axis='x')
ax.set_title('ISO18571',fontsize=20,fontweight='bold')

print('Average: {} \nRange: {}-{}'.format(df_BC['Overall Score'].mean().round(2),
                                           min(df_BC['Overall Score'].round(2)),
                                           max(df_BC['Overall Score'].round(2))))

df_BC.style.apply(select_col, axis=None).format(precision=2).set_caption("ISO 18571 results").set_table_styles(heading).set_properties(**content)
# Out:
# Average: 0.39
# Range: 0.25-0.52
# <style type="text/css">
# #T_31260 caption {
#   text-align: center;
#   font-size: 150%;
#   font-weight: bold;
# }
# #T_31260_row0_col0, #T_31260_row0_col1, #T_31260_row0_col2, #T_31260_row0_col3, #T_31260_row0_col4, #T_31260_row1_col0, #T_31260_row1_col1, #T_31260_row1_col2, #T_31260_row1_col3, #T_31260_row1_col4, #T_31260_row1_col5 {
#   text-align: center;
# }
# #T_31260_row0_col5 {
#   color: crimson;
#   font-weight: bold;
#   text-align: center;
# }
# </style>
# <table id="T_31260">
#   <caption>ISO 18571 results</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_31260_level0_col0" class="col_heading level0 col0" >Test</th>
#       <th id="T_31260_level0_col1" class="col_heading level0 col1" >Corridor Score</th>
#       <th id="T_31260_level0_col2" class="col_heading level0 col2" >Phase Score</th>
#       <th id="T_31260_level0_col3" class="col_heading level0 col3" >Magnitude Score</th>
#       <th id="T_31260_level0_col4" class="col_heading level0 col4" >Slope Score</th>
#       <th id="T_31260_level0_col5" class="col_heading level0 col5" >Overall Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_31260_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_31260_row0_col0" class="data row0 col0" >1_38</td>
#       <td id="T_31260_row0_col1" class="data row0 col1" >0.49</td>
#       <td id="T_31260_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_31260_row0_col3" class="data row0 col3" >0.00</td>
#       <td id="T_31260_row0_col4" class="data row0 col4" >0.27</td>
#       <td id="T_31260_row0_col5" class="data row0 col5" >0.25</td>
#     </tr>
#     <tr>
#       <th id="T_31260_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_31260_row1_col0" class="data row1 col0" >2_07b</td>
#       <td id="T_31260_row1_col1" class="data row1 col1" >0.65</td>
#       <td id="T_31260_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_31260_row1_col3" class="data row1 col3" >0.71</td>
#       <td id="T_31260_row1_col4" class="data row1 col4" >0.59</td>
#       <td id="T_31260_row1_col5" class="data row1 col5" >0.52</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### Anterior-Posterior tests

# %%
df_BC=df_res.loc[df_res.index[[0,1,3]]]
fig, ax = plt.subplots(figsize=(2, 3))
br1 = np.arange(len(df_BC))
ax.bar(br1,df_BC['Overall Score'].values,**B1)
plt.xticks(range(len(df_BC)), df_BC['Test'], rotation=0)
ax.set_ylim([0,1])
ax.set_yticks([0.5,0.58,0.80,0.94,1])
ax.grid(axis='x')
ax.set_title('ISO18571',fontsize=20,fontweight='bold')

print('Average: {} \nRange: {}-{}'.format(df_BC['Overall Score'].mean().round(2),
                                           min(df_BC['Overall Score'].round(2)),
                                           max(df_BC['Overall Score'].round(2))))

df_BC.style.apply(select_col, axis=None).format(precision=2).set_caption("ISO 18571 results").set_table_styles(heading).set_properties(**content)
# Out:
# Average: 0.54
# Range: 0.28-0.73
# <style type="text/css">
# #T_7d498 caption {
#   text-align: center;
#   font-size: 150%;
#   font-weight: bold;
# }
# #T_7d498_row0_col0, #T_7d498_row0_col1, #T_7d498_row0_col2, #T_7d498_row0_col3, #T_7d498_row0_col4, #T_7d498_row0_col5, #T_7d498_row1_col0, #T_7d498_row1_col1, #T_7d498_row1_col2, #T_7d498_row1_col3, #T_7d498_row1_col4, #T_7d498_row1_col5, #T_7d498_row2_col0, #T_7d498_row2_col1, #T_7d498_row2_col2, #T_7d498_row2_col3, #T_7d498_row2_col4 {
#   text-align: center;
# }
# #T_7d498_row2_col5 {
#   color: crimson;
#   font-weight: bold;
#   text-align: center;
# }
# </style>
# <table id="T_7d498">
#   <caption>ISO 18571 results</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d498_level0_col0" class="col_heading level0 col0" >Test</th>
#       <th id="T_7d498_level0_col1" class="col_heading level0 col1" >Corridor Score</th>
#       <th id="T_7d498_level0_col2" class="col_heading level0 col2" >Phase Score</th>
#       <th id="T_7d498_level0_col3" class="col_heading level0 col3" >Magnitude Score</th>
#       <th id="T_7d498_level0_col4" class="col_heading level0 col4" >Slope Score</th>
#       <th id="T_7d498_level0_col5" class="col_heading level0 col5" >Overall Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d498_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7d498_row0_col0" class="data row0 col0" >1_34</td>
#       <td id="T_7d498_row0_col1" class="data row0 col1" >0.64</td>
#       <td id="T_7d498_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_7d498_row0_col3" class="data row0 col3" >0.71</td>
#       <td id="T_7d498_row0_col4" class="data row0 col4" >0.65</td>
#       <td id="T_7d498_row0_col5" class="data row0 col5" >0.73</td>
#     </tr>
#     <tr>
#       <th id="T_7d498_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7d498_row1_col0" class="data row1 col0" >1_37</td>
#       <td id="T_7d498_row1_col1" class="data row1 col1" >0.55</td>
#       <td id="T_7d498_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_7d498_row1_col3" class="data row1 col3" >0.35</td>
#       <td id="T_7d498_row1_col4" class="data row1 col4" >0.56</td>
#       <td id="T_7d498_row1_col5" class="data row1 col5" >0.60</td>
#     </tr>
#     <tr>
#       <th id="T_7d498_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_7d498_row2_col0" class="data row2 col0" >2_06</td>
#       <td id="T_7d498_row2_col1" class="data row2 col1" >0.48</td>
#       <td id="T_7d498_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_7d498_row2_col3" class="data row2 col3" >0.00</td>
#       <td id="T_7d498_row2_col4" class="data row2 col4" >0.44</td>
#       <td id="T_7d498_row2_col5" class="data row2 col5" >0.28</td>
#     </tr>
#   </tbody>
# </table>
